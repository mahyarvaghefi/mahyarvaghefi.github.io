# %% [markdown]
# <div align='center'>
# <h2 style="color: #002868;">BANA 3308 - Introduction to Business Analytics</h2>
# <h4>Instructor: Mahyar S Vaghefi</h4>
# <h4>University of Texas Arlington</h4>
# </div>

# %%
# Student Name:
# Student Id:

# %% [markdown]
# <h1 align='center' style="color: #BF0A30;">Assignment #1</h1>

# %% [markdown]
# <h3> Question 1: NumPy Fundamentals (20 points)</h3>
# <img src='https://www.dropbox.com/scl/fi/wjy8j68lydgb7w6y704de/ChatGPT-Image-Feb-9-2026-at-12_01_48-AM.png?rlkey=qov2ak8l2c4oqe9yobhk3t1b9&raw=1' width=600 />
#
# Complete the following steps in order. Each step builds on the previous one.
#
# <h4>Part 1: Import and Setup (2 points)</h4>
# <ul>
#     <li>Import NumPy</li>
#     <li>Set seed to <code>2026</code> for reproducibility</li>
# </ul>
# <h4>Part 2: Create a 1D Array (3 points)</h4>
# <ol type="a">
#     <li>Create a 1D array called <code>array_1d</code> containing integers from 20 to 49 (30 elements total) using <code>np.arange()</code></li>
#     <li>Print the array</li>
#     <li>Print its shape using <code>.shape</code></li>
#     <li>Print its number of dimensions using <code>.ndim</code></li>
#     <li>Verify it has exactly 30 elements using <code>.size</code></li>
# </ol>
#
# <h4>Part 3: Reshape to 2D Array (3 points)</h4>
# <ol type="a">
#     <li>Reshape <code>array_1d</code> into a 5×6 matrix called <code>array_2d</code></li>
#     <li>Print the reshaped array</li>
#     <li>Print its new shape</li>
#     <li>Confirm it's now 2-dimensional using <code>.ndim</code></li>
# </ol>
#
# <h4>Part 4: Create Random Arrays (3 points)</h4>
# <p>Create the following random arrays:</p>
# <ol type="a">
#     <li><code>small_random</code>: A 6×6 array of random integers between 1 and 100</li>
#     <li><code>large_random</code>: A 200×200 array of random integers between 0 and 500</li>
#     <li>Print <code>small_random</code> entirely</li>
#     <li>For <code>large_random</code>, print only:
#         <ul>
#             <li>Its shape</li>
#             <li>The top-left 4×4 corner</li>
#             <li>The bottom-right 4×4 corner</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 5: Array Slicing on small_random (3 points)</h4>
# <p>Using the <code>small_random</code> array from Step 4:</p>
# <ol type="a">
#     <li>Extract and print the element at position [3, 4]</li>
#     <li>Extract and print the entire 4th row (index 3)</li>
#     <li>Extract and print the entire 3rd column (index 2)</li>
#     <li>Extract and print the 3×3 submatrix from rows 1-3 and columns 2-4</li>
#     <li>Extract and print the last three rows</li>
# </ol>
#
# <h4>Part 6: Boolean Indexing and Filtering (3 points)</h4>
# <p>Still using <code>small_random</code>:</p>
# <ol type="a">
#     <li>Create a boolean mask for all elements greater than 60</li>
#     <li>Print all values greater than 60</li>
#     <li>Count how many elements are greater than 60</li>
#     <li>Replace all elements less than 25 with 0 (make a copy first to preserve original)</li>
#     <li>Find and print all elements between 30 and 80 (inclusive)</li>
# </ol>
#
# <h4>Part 7: Aggregation Operations (3 points)</h4>
# <p>Using the original <code>small_random</code> array:</p>
# <ol type="a">
#     <li>Calculate and print the total sum of all elements</li>
#     <li>Calculate and print the sum of each row (should get 6 values)</li>
#     <li>Calculate and print the sum of each column (should get 6 values)</li>
#     <li>Find the maximum value in each row</li>
#     <li>Calculate the mean of each column</li>
# </ol>

# %%
# Part 1 - Answer Here

# %%
# Part 2 - Answer Here

# %%
# Part 3 - Answer Here

# %%
# Part 4 - Answer Here

# %%
# Part 5 - Answer Here

# %%
# Part 6 - Answer Here

# %%
# Part 7 - Answer Here

# %% [markdown]
# <h3> Question 2: Array Operations and Broadcasting (20 points)</h3>
#
# <img src='https://www.dropbox.com/scl/fi/h7m5thj1m0v06u36q6mh1/ChatGPT-Image-Feb-9-2026-at-12_06_26-AM.png?rlkey=f8wvisjpegqrwb5831e2ogpf5&raw=1' width=600/>
#
# <p><b>Important:</b> For each operation, you must determine if it's possible. If not possible, explain WHY using array shapes.</p>
#
# <h4>Setup: Create Test Arrays</h4>
# <pre>
# # Create various arrays for testing operations
# A = np.array([[2, 4, 6],
#               [8, 10, 12]])          # Shape: (2, 3)
#
# B = np.array([[1, 3, 5],
#               [7, 9, 11]])           # Shape: (2, 3)
#
# C = np.array([[2, 5],
#               [1, 4],
#               [3, 6]])               # Shape: (3, 2)
#
# D = np.array([[10, 20, 30]])        # Shape: (1, 3)
#
# E = np.array([[50],
#               [100]])                # Shape: (2, 1)
#
# F = np.array([2, 4, 6])             # Shape: (3,)
# </pre>
#
# <h4>Part 1: Element-wise Operations (4 points)</h4>
# <p>Try each operation. If it works, show the result. If it doesn't work, explain why based on shapes.</p>
# <ol type="a">
#     <li><b>Addition:</b>
#         <ul>
#             <li>A + B (Should this work? Try it)</li>
#             <li>A + C (Should this work? Try it)</li>
#             <li>A + 20 (scalar addition)</li>
#         </ul>
#     </li>
#     <li><b>Subtraction:</b>
#         <ul>
#             <li>B - A</li>
#             <li>C - A</li>
#         </ul>
#     </li>
#     <li><b>Multiplication (element-wise):</b>
#         <ul>
#             <li>A * B</li>
#             <li>A * 3 (scalar multiplication)</li>
#         </ul>
#     </li>
#     <li><b>Division:</b>
#         <ul>
#             <li>A / B</li>
#         </ul>
#     </li>
#     <li><b>Exponential:</b>
#         <ul>
#             <li>A ** 3 (cubing)</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 2: Transpose Operations (4 points)</h4>
# <ol type="a">
#     <li>Find the transpose of A using <code>A.T</code> and print its shape</li>
#     <li>Find the transpose of C and print its shape</li>
#     <li>Can you add A + C.T? Try it and explain why it works or doesn't work</li>
#     <li>What about A.T + C? Try it and explain</li>
# </ol>
#
# <h4>Part 3: Broadcasting (5 points)</h4>
# <p>For each operation, predict if broadcasting will work, then verify:</p>
# <ol type="a">
#     <li><b>A + D:</b>
#         <ul>
#             <li>A has shape (2, 3), D has shape (1, 3)</li>
#             <li>Predict: Will this work? Why?</li>
#             <li>Try it and verify</li>
#         </ul>
#     </li>
#     <li><b>A + E:</b>
#         <ul>
#             <li>A has shape (2, 3), E has shape (2, 1)</li>
#             <li>Predict: Will this work? Why?</li>
#             <li>Try it and verify</li>
#         </ul>
#     </li>
#     <li><b>A + F:</b>
#         <ul>
#             <li>A has shape (2, 3), F has shape (3,)</li>
#             <li>Predict: Will this work? Why?</li>
#             <li>Try it and verify</li>
#         </ul>
#     </li>
#     <li><b>D + E:</b>
#         <ul>
#             <li>D has shape (1, 3), E has shape (2, 1)</li>
#             <li>Predict: Will this work? What will be the result shape?</li>
#             <li>Try it and verify</li>
#         </ul>
#     </li>
#     <li><b>C + D:</b>
#         <ul>
#             <li>C has shape (3, 2), D has shape (1, 3)</li>
#             <li>Predict: Will this work? Why or why not?</li>
#             <li>Try it (use try/except to catch errors)</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 4: Matrix Multiplication (5 points)</h4>
# <p><b>Note:</b> Matrix multiplication uses <code>@</code> operator or <code>np.dot()</code></p>
# <p><b>Rule:</b> For A @ B to work, columns of A must equal rows of B</p>
#
# <ol type="a">
#     <li><b>A @ B:</b>
#         <ul>
#             <li>A is (2, 3), B is (2, 3)</li>
#             <li>Will this work? Why or why not?</li>
#             <li>Try it with error handling</li>
#         </ul>
#     </li>
#     <li><b>A @ C:</b>
#         <ul>
#             <li>A is (2, 3), C is (3, 2)</li>
#             <li>Will this work? What will be the result shape?</li>
#             <li>Try it and verify</li>
#         </ul>
#     </li>
#     <li><b>C @ A:</b>
#         <ul>
#             <li>C is (3, 2), A is (2, 3)</li>
#             <li>Will this work? What will be the result shape?</li>
#             <li>Try it and verify</li>
#         </ul>
#     </li>
#     <li><b>A @ A.T:</b>
#         <ul>
#             <li>What are the shapes involved?</li>
#             <li>Calculate and show result</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 5: Summary Questions (2 points)</h4>
# <p>Answer these conceptual questions based on your experiments:</p>
# <ol>
#     <li>When can two arrays be added/subtracted/multiplied element-wise?</li>
#     <li>What is the rule for broadcasting to work?</li>
#     <li>What is the difference between * and @ for arrays?</li>
#     <li>When is matrix multiplication possible between two arrays?</li>
# </ol>
#
# <hr>
#
# <h4>Important: Submission Format</h4>
# <p>For operations that fail, use this format:</p>
# <pre>
# try:
#     result = A + C
#     print("Result:", result)
# except ValueError as e:
#     print("Operation failed!")
#     print("Reason: A has shape", A.shape, "and C has shape", C.shape)
#     print("These shapes are incompatible for element-wise operations")
#     print("Error message:", e)
# </pre>

# %%
# Setup

# %%
# Part 1 - Answer Here

# %%
# Part 2 - Answer Here

# %%
# Part 3 - Answer Here

# %%
# Part 4 - Answer Here

# %%
# Part 5 - Answer Here

# %% [markdown]
# <h3>Question 3: Image Processing with NumPy (20 points)</h3>
# <img src='https://www.dropbox.com/scl/fi/h355az7jkqncc4gkk6vii/ChatGPT-Image-Feb-9-2026-at-12_10_10-AM.png?rlkey=qnhzumo4zco7g2n2jcbkh4g9z&raw=1' width=600 />
# <p>You have been provided with an image file called <code>texas_playground.jpg</code>. This image features a Texas-themed scene with a Lone Star, desert mesas, cacti, a ranch house, a sun, and a Texas flag stripe. This assignment will help you understand how images are represented as 3D NumPy arrays.</p>
#
# <h4>Part 1: Loading and Understanding the Image (4 points)</h4>
# <pre>
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# # Load the image
# img = mpimg.imread('texas_playground.jpg')
# </pre>
#
# <ol type="a">
#     <li><b>Basic Properties:</b>
#         <ul>
#             <li>Print the shape of the image array</li>
#             <li>What do the three dimensions represent?</li>
#             <li>Print the data type of the array</li>
#             <li>What is the range of pixel values? (find min and max)</li>
#         </ul>
#     </li>
#     <li><b>Display the Image:</b>
#         <ul>
#             <li>Use <code>plt.imshow(img)</code> to display the full image</li>
#             <li>Print the image dimensions (height × width)</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 2: Color Channel Analysis (5 points)</h4>
# <p>Remember: Images have 3 channels - Red (index 0), Green (index 1), Blue (index 2)</p>
#
# <ol type="a">
#     <li><b>Extract Individual Channels:</b>
#         <ul>
#             <li>Extract the red channel: <code>red_channel = img[:, :, 0]</code></li>
#             <li>Extract the green channel</li>
#             <li>Extract the blue channel</li>
#             <li>Print the shape of each channel (should be 2D arrays)</li>
#         </ul>
#     </li>
#     <li><b>Visualize Channels:</b>
#         <ul>
#             <li>Display each channel as a grayscale image using <code>plt.imshow(channel, cmap='gray')</code></li>
#             <li>Which channel shows the sun most brightly?</li>
#         </ul>
#     </li>
#     <li><b>Channel Statistics:</b>
#         <ul>
#             <li>Calculate the mean intensity of each channel</li>
#             <li>Which channel has the highest average intensity?</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 3: Region Extraction Using Slicing (4 points)</h4>
# <p>Use slicing to extract specific regions of the Texas scene:</p>
#
# <ol type="a">
#     <li><b>Extract the Sun:</b>
#         <ul>
#             <li>The sun is approximately at pixels [50:190, 730:870]</li>
#             <li>Extract this region: <code>sun_region = img[50:190, 730:870, :]</code></li>
#             <li>Display the extracted sun region</li>
#             <li>What is the shape of this sub-image?</li>
#         </ul>
#     </li>
#     <li><b>Extract the Lone Star:</b>
#         <ul>
#             <li>The star is approximately at pixels [80:300, 370:600]</li>
#             <li>Extract and display this region</li>
#             <li>Calculate the mean pixel value for each channel (Red, Green, Blue) separately in the star region. You should get three values — one per channel.</li>
#         </ul>
#     </li>
#     <li><b>Extract the Texas Flag Stripe:</b>
#         <ul>
#             <li>The flag stripe is at approximately pixels [570:, :] (bottom of image)</li>
#             <li>Extract and display this region</li>
#             <li>What is the shape of the flag region?</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 4: Color Detection and Masking (4 points)</h4>
# <p>Use boolean indexing to find specific colors in the image:</p>
#
# <ol type="a">
#     <li><b>Find Yellow Pixels (the Sun):</b>
#         <ul>
#             <li>Yellow has high red and green, but low blue</li>
#             <li>Create a mask: pixels where R > 200 AND G > 180 AND B < 100</li>
#             <li>Count how many pixels match this condition</li>
#         </ul>
#         <pre>
# # Hint structure:
# yellow_mask = (img[:,:,0] > 200) & (img[:,:,1] > 180) & (img[:,:,2] < 100)
# yellow_pixel_count = np.sum(yellow_mask)
#         </pre>
#     </li>
#     <li><b>Find Red Pixels (Flag Red Stripe and Barn):</b>
#         <ul>
#             <li>Create a mask: R > 150 AND R > G AND R > B</li>
#             <li>What percentage of the image is red?</li>
#         </ul>
#     </li>
#     <li><b>Find Blue Pixels (Sky and Flag Blue Stripe):</b>
#         <ul>
#             <li>Create appropriate conditions for blue regions</li>
#             <li>Count the blue pixels</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 5: Image Manipulation (3 points)</h4>
# <p>Create modified versions of the image:</p>
#
# <ol type="a">
#     <li><b>Create a Night Version:</b>
#         <ul>
#             <li>Make a copy: <code>night_img = img.copy()</code></li>
#             <li>Reduce all pixel values by 60%: <code>night_img = (img * 0.4).astype(np.uint8)</code></li>
#             <li>Display the "night" version</li>
#         </ul>
#     </li>
#     <li><b>Swap Color Channels:</b>
#         <ul>
#             <li>Create a version where red and blue channels are swapped</li>
#             <li>How does this change the appearance of the Texas flag?</li>
#         </ul>
#     </li>
# </ol>

# %%
# Setup

# %%
# Part 1a - Answer Here

# %%
# Part 1b - Answer Here

# %%
# Part 2a - Answer Here

# %%
# Part 2b - Answer Here

# %%
# Part 2c - Answer Here

# %%
# Part 3a - Answer Here

# %%
# Part 3b - Answer Here

# %%
# Part 3c - Answer Here

# %%
# Part 4a - Answer Here

# %%
# Part 4b - Answer Here

# %%
# Part 4c - Answer Here

# %%
# Part 5a - Answer Here

# %%
# Part 5b - Answer Here

# %% [markdown]
# <h3>Question 4: Pandas DataFrame Operations (20 points)</h3>
# <img src='https://www.dropbox.com/scl/fi/4a4jw3acpreekd2exkiah/ChatGPT-Image-Feb-9-2026-at-12_12_53-AM.png?rlkey=8cojvgug41zsx7hkbemvn2rlf&raw=1' width=600 />
#
# <p>This question tests your ability to create, access, slice, filter, and concatenate Pandas DataFrames.</p>
#
# <h4>Part 1: Creating a DataFrame and Reading CSV (5 points)</h4>
# <ol type="a">
#     <li>Import pandas as pd</li>
#     <li>Create the following DataFrame manually using a dictionary:
# <pre>
# data = {
#     'City': ['Dallas', 'Austin', 'Houston', 'San Antonio', 'Fort Worth', 'El Paso'],
#     'Population': [1340000, 979000, 2300000, 1470000, 958000, 678000],
#     'Avg_Temp_F': [96, 97, 95, 95, 96, 94],
#     'State_Rank': [3, 4, 1, 2, 5, 6]
# }
# tx_cities = pd.DataFrame(data)
# </pre>
#     </li>
#     <li>Print the DataFrame</li>
#     <li>Print its <code>.shape</code>, <code>.dtypes</code>, and <code>.columns</code></li>
#     <li>Use <code>pd.read_csv()</code> to read the file <code>tx_sales.csv</code> into a DataFrame called <code>sales_df</code> and print the first 5 rows using <code>.head()</code>
# <pre>
# # The CSV file tx_sales.csv has the following columns:
# # OrderID, Product, Category, City, Revenue, Units
# </pre>
#     </li>
# </ol>
#
# <h4>Part 2: Accessing and Creating Columns (5 points)</h4>
# <p>Using the <code>tx_cities</code> DataFrame:</p>
# <ol type="a">
#     <li>Access the 'City' column using bracket notation: <code>tx_cities['City']</code></li>
#     <li>Access the 'Population' column using dot notation: <code>tx_cities.Population</code></li>
#     <li>Create a new column called <code>Pop_Millions</code> that converts Population to millions (divide by 1,000,000)</li>
#     <li>Create a new column called <code>Is_Large</code> that is <code>True</code> if Population > 1,000,000, else <code>False</code></li>
# </ol>
#
# <h4>Part 3: Slicing with .loc and .iloc (5 points)</h4>
# <ol type="a">
#     <li>Use <code>.iloc</code> to select the first 3 rows</li>
#     <li>Use <code>.iloc</code> to select rows 1 through 4 and columns 0 through 2</li>
#     <li>Use <code>.loc</code> to select rows 0 through 3 and the columns 'City' and 'Population'</li>
#     <li>Explain: What is the difference between <code>.loc[0:3]</code> and <code>.iloc[0:3]</code>?</li>
# </ol>
#
# <h4>Part 4: Filtering and Concatenation (5 points)</h4>
# <ol type="a">
#     <li>Filter <code>tx_cities</code> to show only cities with Population greater than 1,000,000</li>
#     <li>Filter to show cities where <code>Avg_Temp_F >= 96</code></li>
#     <li>Combine both conditions: Population > 1,000,000 <b>AND</b> Avg_Temp_F >= 96</li>
#     <li>After filtering for large cities (Population > 1,000,000), reset the index using <code>reset_index(drop=True)</code></li>
#     <li>Create a second small DataFrame:
# <pre>
# new_cities = pd.DataFrame({
#     'City': ['Lubbock', 'Amarillo'],
#     'Population': [264000, 200000],
#     'Avg_Temp_F': [93, 91],
#     'State_Rank': [11, 14]
# })
# </pre>
#     Concatenate <code>tx_cities</code> and <code>new_cities</code> using <code>pd.concat()</code> with <code>ignore_index=True</code>
#     </li>
# </ol>

# %%
# Part 1 - Answer Here

# %%
# Part 2 - Answer Here

# %%
# Part 3 - Answer Here

# %%
# Part 4 - Answer Here

# %% [markdown]
# <h3>Question 5: Pandas Merge and GroupBy (20 points)</h3>
#
# <img src='https://www.dropbox.com/scl/fi/e6kmdl5prfh4brvooj4hx/ChatGPT-Image-Feb-9-2026-at-12_18_04-AM.png?rlkey=iqx3av7ykb9vqzko1ahng0e6y&raw=1' width=600>
#
# <h4>Setup: Create the DataFrames</h4>
# <pre>
# import pandas as pd
#
# # Store information
# stores = pd.DataFrame({
#     'StoreID': ['S1', 'S2', 'S3', 'S4'],
#     'StoreName': ['Dallas Central', 'Austin Main', 'Houston East', 'San Antonio Plaza'],
#     'City': ['Dallas', 'Austin', 'Houston', 'San Antonio']
# })
#
# # Sales data (one-to-many: each store has multiple sales)
# sales = pd.DataFrame({
#     'SaleID': [101, 102, 103, 104, 105, 106, 107, 108],
#     'StoreID': ['S1', 'S1', 'S2', 'S2', 'S3', 'S3', 'S4', 'S5'],
#     'Product': ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Laptop', 'Desk', 'Chair', 'Lamp'],
#     'Category': ['Electronics', 'Electronics', 'Electronics', 'Electronics', 'Electronics', 'Furniture', 'Furniture', 'Furniture'],
#     'Revenue': [1200, 25, 75, 300, 1100, 350, 150, 45],
#     'Quantity': [1, 5, 3, 1, 2, 1, 3, 2]
# })
# </pre>
#
# <h4>Part 1: Merge Operations (10 points)</h4>
# <ol type="a">
#     <li><b>Inner Merge:</b> Merge <code>stores</code> and <code>sales</code> on <code>'StoreID'</code> using an inner join.
#         <ul>
#             <li>How many rows are in the result?</li>
#             <li>Which StoreID(s) were excluded and why?</li>
#         </ul>
#     </li>
#     <li><b>Left Merge:</b> Merge with <code>how='left'</code> (stores on the left).
#         <ul>
#             <li>Are all stores preserved? Which sale is excluded?</li>
#         </ul>
#     </li>
#     <li><b>Right Merge:</b> Merge with <code>how='right'</code> (sales on the right).
#         <ul>
#             <li>What happens to StoreID 'S5' which has no store info?</li>
#         </ul>
#     </li>
#     <li><b>Outer Merge:</b> Merge with <code>how='outer'</code>.
#         <ul>
#             <li>How many rows are in the result?</li>
#             <li>Where do NaN values appear and why?</li>
#         </ul>
#     </li>
# </ol>
#
# <h4>Part 2: GroupBy Operations (10 points)</h4>
# <p>Using the <code>sales</code> DataFrame:</p>
# <ol type="a">
#     <li>Use <code>groupby('Category')</code> to calculate the <b>total Revenue</b> per category using <code>.sum()</code></li>
#     <li>Use <code>groupby('StoreID')</code> to count the number of sales per store using <code>.size()</code></li>
#     <li>Use <code>groupby('Category')['Quantity'].mean()</code> to find the average quantity sold per category</li>
#     <li>Use <code>.agg()</code> to get the <b>sum</b>, <b>mean</b>, and <b>count</b> of Revenue grouped by Category:
# <pre>
# sales.groupby('Category')['Revenue'].agg(['sum', 'mean', 'count'])
# </pre>
#     </li>
#     <li>Group by <b>both</b> StoreID and Category, and compute the total Revenue. Then use <code>.reset_index()</code> to convert the result into a regular DataFrame:
# <pre>
# sales.groupby(['StoreID', 'Category'])['Revenue'].sum().reset_index()
# </pre>
#     </li>
# </ol>

# %%
# Setup

# %%
# Part 1a - Inner Merge

# %%
# Part 1b - Left Merge

# %%
# Part 1c - Right Merge

# %%
# Part 1d - Outer Merge

# %%
# Part 2a - Total Revenue by Category

# %%
# Part 2b - Count by Store

# %%
# Part 2c - Mean Quantity by Category

# %%
# Part 2d - Agg multiple stats

# %%
# Part 2e - GroupBy multiple columns

# %% [markdown]
# ### 📊 Assignment #1 - Grading Overview
#
# | Question | Description | Points |
# |----------|-------------|--------|
# | **Question 1** | NumPy Fundamentals (7 parts) | **20** |
# | **Question 2** | Array Operations & Broadcasting (5 parts) | **20** |
# | **Question 3** | Image Processing with NumPy (5 parts) | **20** |
# | **Question 4** | Pandas DataFrame Operations (4 parts) | **20** |
# | **Question 5** | Pandas Merge & GroupBy (2 parts) | **20** |
# | | **TOTAL** | **100** |
#
# #### 📅 Submission Requirements:
# - ✅ Submit as `.ipynb` file with all outputs visible
# - ✅ Include your name and student ID
# - ✅ All code cells must be executed
# - ✅ Upload the `texas_playground.jpg` and `tx_sales.csv` files alongside your notebook
# - ⚠️ **Deadline: Wednesday, February 25 at 1:00 PM**
# - ❌ **No late submissions accepted**
